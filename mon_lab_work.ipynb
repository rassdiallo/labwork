# %% [markdown]
# # Data analytics with `pandas` and `matplotlib`

# %% [markdown]
# In this task, you are asked to analyze cryptocurrency data using the pandas and matplotlib libraries.
# The task looks like a laboratory work in which you have to fill in the missing cells and answer a series of questions.
#  - [Official pandas documentation](https://pandas.pydata.org/)
#  - [Official matplotlib documentation](https://matplotlib.org/index.html)

# %% [markdown]
# > **Reminder**
# >
# >Minimum points for crediting this work - **1 point**. If you do not score here 1 point, then you get a failure throughout the course (see slides from the introductory presentation).

# %% [markdown]
# ## 1. Data (2 points)

# %% [markdown]
# Downloading data for work:

# %%
# %%bash
# gdown 1e-Q_15W7ExExQarKqgjrtoO-LHi9oJs3
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1e-Q_15W7ExExQarKqgjrtoO-LHi9oJs3
# To: /content/coins.csv
# 100%|██████████| 3.98M/3.98M [00:00<00:00, 190MB/s]

# %% [markdown]
# Let's start with the necessary preparations.

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import ipywidgets  # Библиотека для интерактивных контролов в jupyter notebook'е

# %matplotlib inline

# %% [markdown]
# #### Load a pre-prepared dataset from *"coins.csv"* file. Create an object of type `pandas.DataFrame` named `coins` and select the date column as the index.

# %%
# load dataset and creating the dataframe
coins = pd.read_csv('coins.csv')

# Select the date column as the index.
coins['datetime'] = pd.to_datetime(coins['date'])
coins.set_index('datetime', inplace=True)

# %% [markdown]
# Let's see what happened

# %%
coins.head(4)
# Out:
#                   date   price  txCount      txVolume  activeAddresses symbol  \
# datetime
# 2013-04-28  2013-04-28  135.30  41702.0  6.879868e+07         117984.0    BTC
# 2013-04-28  2013-04-28    4.30   9174.0  4.431952e+07          17216.0    LTC
# 2013-04-29  2013-04-29  134.44  51602.0  1.138128e+08          86925.0    BTC
# 2013-04-29  2013-04-29    4.37   9275.0  3.647810e+07          18395.0    LTC
#
#                 name    open    high     low   close  volume        market
# datetime
# 2013-04-28   Bitcoin  135.30  135.98  132.10  134.21     0.0  1.500520e+09
# 2013-04-28  Litecoin    4.30    4.40    4.18    4.35     0.0  7.377340e+07
# 2013-04-29   Bitcoin  134.44  147.49  134.00  144.54     0.0  1.491160e+09
# 2013-04-29  Litecoin    4.37    4.57    4.23    4.38     0.0  7.495270e+07

# %% [markdown]
# Let's explain the values ​​stored in the columns
#  - date - measurement date
#  - name - full name of the coin
#  - symbol - abbreviated name of the coin
#  - price - average coin price per trading day in USD
#  - txCount - the number of transactions in the network of this coin
#  - txVolume - the volume of coins transferred between addresses in the network of this coin
#  - activeAddresses - the number of addresses that made transactions on this day in the network of this coin
#  - open - the price of the coin at the beginning of trading on the given day
#  - close - the price of the coin at the end of the trading day
#  - high - the highest price of this coin during the current trading day
#  - low - the lowest price of the given coin during the given trading day
#  - volume - trading volume of this coin on exchanges on a given day
#  - market - capitalization of this coin on a given day

# %% [markdown]
# Let's examine the data. Answer the following questions (insert cells with code and text below):

# %% [markdown]
# ### 1. How many different coins are there in the dataset? (0.4 points)

# %%
# We can count coins based on their symbols
coins_count = coins['symbol'].nunique()

print("The answer is: " + str(coins_count))
# Out:
# The answer is: 66

# %% [markdown]
# **66** is the number of different coins in the dataset

# %% [markdown]
# ### 2. For what period do we have data? (0.4 points)

# %%
# We can use the date column in the dataset to find the period
# By choosing the minimum date and maximum date in the column
min_date = coins.index.min()
max_date = coins.index.max()

print("The period starts from ", min_date.date(), " to ", max_date.date())
# Out:
# The period starts from  2013-04-28  to  2018-06-06

# %% [markdown]
# The period covered starts on **2013-04-28** and ends on **2018-06-06**.

# %% [markdown]
# ### 3. Are there gaps in the data? What is the nature of these omissions, what are they most likely caused by? (0.5 points)

# %%
# Date range
d_range = pd.date_range(start=min_date, end=max_date)

# Missing days
print("Number of missing days are:", len(d_range.difference(coins.index)), "\n")

# Empty cells count by column
print(coins.isna().sum())
# Out:
# Number of missing days are: 0
#
# date                  0
# price               327
# txCount            1520
# txVolume           1830
# activeAddresses    1520
# symbol                0
# name                  0
# open                  0
# high                  0
# low                   0
# close                 0
# volume                0
# market                0
# dtype: int64

# %% [markdown]
# There are **no missing days** in the dataset from the beginning till the end.<br>
#
# However there are **327 empty cells in the price column**, this could be due to the lack of information regarding the concerned currency.
# <br>
#
# There are empty cells as well in other columns such are **txCount**, **activeAddresses**, **txVolume**, **txCount**.

# %% [markdown]
# ### 4. Which coin had the highest price and when? (0.2 points)

# %%
# We can get the row with highest price
highest_price = coins[coins['price'] == coins['price'].max()]

print("The name of the highest price coin is", highest_price["name"].values[0], "and the date is", highest_price["date"].values[0])
# Out:
# The name of the highest price coin is Bitcoin and the date is 2017-12-17

# %% [markdown]
# The highest price coin is the **Bitcoin** and the date was **2017-12-17**.

# %% [markdown]
# ### 5. Which coin has the highest and lowest total capitalization? Build a pie chart with proportions. (0.5 points)

# %%
# Get dataframe of total capitalization
# We could group with symbols as well but that wouldn't give us names
total_cap = coins.groupby('name')['market'].max()

print("The coin with the highest capitalization is", total_cap.idxmax(), "with capitalization value of ", total_cap.max())
print("The coin with the highest capitalization is", total_cap.idxmin(), "with capitalization value of ", total_cap.min())
# Out:
# The coin with the highest capitalization is Bitcoin with capitalization value of  326141000000.0
# The coin with the highest capitalization is KingN Coin with capitalization value of  219933.0

# %%
# The pie chart with proportions

def pie_chart(coins):
    coin_caps = coins.groupby('symbol')['market'].max()
    sizes = coin_caps.values

    explode = [0.1 if coin == total_cap.idxmax() else 0 for coin in coin_caps.index]

    plt.figure(figsize=(10, 10))
    patches, _, _ = plt.pie(sizes, explode=explode, autopct='%1.1f%%', startangle=140)

    plt.legend(patches, coin_caps.index, loc="center left", bbox_to_anchor=(1, 0.5), title="Coins", fontsize='small')

    plt.title('Chart with proportions')
    plt.axis('equal')
    plt.tight_layout()
    plt.show()

pie_chart(coins)

# %% [markdown]
# ## 2. Visualization (1 point)

# %% [markdown]
# The most interesting part of the analyst's job is to carefully look at correctly chosen and constructed charts.

# %% [markdown]
# **Implement a function to visualize the prices of the selected currency for the selected date range.**

# %% [markdown]
# The chart should show the start and end prices of sales. As well as the minimum and maximum price for that day.
# Label the graph and coordinate axes. Add a grid. Increase the image size.
# You can try using `matplotlib.finance.candlestick_ohlc` (`mpl_finance.candlestick_ohlc`), but you can do without it.

# %%
def plot_fancy_price_action(coins, symbol, start_date, end_date):
    coin = coins[coins['symbol'] == symbol]
    d_range = coin.loc[start_date:end_date]

    plt.figure(figsize=(12, 8))

    plt.plot(d_range.index, d_range['open'], label='Start Price', marker='o')
    plt.plot(d_range.index, d_range['close'], label='End Price', marker='o')
    plt.scatter(d_range.index, d_range['high'], label='Max Price', marker='^', color='red')
    plt.scatter(d_range.index, d_range['low'], label='Min Price', marker='v', color='green')
    coin_name = coin['name'][0]
    plt.title(f'Price action for {coin_name} (from {start_date} to {end_date})')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()

    plt.show()

# %% [markdown]
# Let's see what happened:

# %%
plot_fancy_price_action(coins=coins, symbol='VERI', start_date='2013-06-01', end_date='2019-06-30')

# %% [markdown]
# There is no data science in this task. It's just that an analyst should be able to build charts, or know ready-made tools.

# %% [markdown]
# ## 3. Pump and dump (1 point)

# %% [markdown]
# Cryptocurrency exchanges still remain a marginal place, a kind of wild west of the financial world. As a consequence, schemes thrive here regarding
# honest withdrawal of money. One of them is **pump'n'dump** (pump and dump).
#
# She looks like this. Several large players or many small ones agree to buy together an obscure coin with a low price and trading volume. This leads to an instant rise in price (pump), then inexperienced players come in the hope of making money on such growth. At this point, the organizers of the scheme will start selling everything (dump). The whole process takes from several minutes to several hours.

# %% [markdown]
# Your task is to **find the strongest pump'n'dump** of the coin in the given time period. To do this, for each day, we define the number `pnd` equal to the ratio of the maximum price of the coin on the given day to the maximum of the opening and closing prices on the same day. We need to find the day when `pnd` was maximum and the value of `pnd`.

# %%
def find_most_severe_pump_and_dump(coins, symbol, start_date, end_date):
    coin = coins[coins['symbol'] == symbol]
    d_range = coin.loc[start_date:end_date]

    # Getting the ratio
    d_range['pnd'] = d_range['high'] / d_range[['open', 'close']].max(axis=1)

    pnd_day = d_range['pnd'].idxmax()
    pnd_value = d_range.loc[pnd_day, 'pnd']
    coin_name = coin['name'][0]

    print("The strongest pump'n'dump for", coin_name, "occurred on", pnd_day.date(),"with a PnD ratio of", f"{pnd_value:.2f}")
    pd.options.mode.chained_assignment = None

# %%
find_most_severe_pump_and_dump(coins, symbol='BTC', start_date='2017-06-01', end_date='2018-06-01')
# Out:
# The strongest pump'n'dump for Bitcoin occurred on 2017-11-29 with a PnD ratio of 1.14

# %% [markdown]
# Compare these values ​​for different coins:

# %%
unique_symbols = coins['symbol'].unique()

for symbol in unique_symbols:
  try:
    find_most_severe_pump_and_dump(coins, symbol=symbol, start_date='2017-06-01', end_date='2018-06-01')
  except:
    pass
# Out:
# The strongest pump'n'dump for Bitcoin occurred on 2017-11-29 with a PnD ratio of 1.14
# The strongest pump'n'dump for Litecoin occurred on 2018-02-07 with a PnD ratio of 1.11
# The strongest pump'n'dump for Dogecoin occurred on 2017-12-17 with a PnD ratio of 1.27
# The strongest pump'n'dump for Vertcoin occurred on 2017-10-22 with a PnD ratio of 1.40
# The strongest pump'n'dump for DigiByte occurred on 2017-12-17 with a PnD ratio of 1.36
# The strongest pump'n'dump for Dash occurred on 2017-11-29 with a PnD ratio of 1.20
# The strongest pump'n'dump for MaidSafeCoin occurred on 2017-06-07 with a PnD ratio of 1.29
# The strongest pump'n'dump for Stellar occurred on 2017-10-16 with a PnD ratio of 1.33
# The strongest pump'n'dump for Verge occurred on 2017-12-17 with a PnD ratio of 1.73
# The strongest pump'n'dump for Tether occurred on 2017-11-12 with a PnD ratio of 1.10
# The strongest pump'n'dump for NEM occurred on 2018-01-04 with a PnD ratio of 1.14
# The strongest pump'n'dump for Ethereum occurred on 2017-07-18 with a PnD ratio of 1.14
# The strongest pump'n'dump for Augur occurred on 2018-05-11 with a PnD ratio of 1.48
# The strongest pump'n'dump for Decred occurred on 2018-04-25 with a PnD ratio of 1.81
# The strongest pump'n'dump for PIVX occurred on 2017-11-28 with a PnD ratio of 1.36
# The strongest pump'n'dump for Lisk occurred on 2017-06-07 with a PnD ratio of 1.44
# The strongest pump'n'dump for Waves occurred on 2017-06-03 with a PnD ratio of 1.25
# The strongest pump'n'dump for Ethereum Classic occurred on 2017-12-19 with a PnD ratio of 1.15
# The strongest pump'n'dump for NEO occurred on 2017-06-10 with a PnD ratio of 1.23
# The strongest pump'n'dump for Zcash occurred on 2017-09-28 with a PnD ratio of 1.33
# The strongest pump'n'dump for Golem occurred on 2018-04-13 with a PnD ratio of 1.69
# The strongest pump'n'dump for Gnosis occurred on 2018-03-25 with a PnD ratio of 1.65
# The strongest pump'n'dump for Aragon occurred on 2017-10-13 with a PnD ratio of 1.73
# The strongest pump'n'dump for Aeternity occurred on 2017-08-06 with a PnD ratio of 1.75
# The strongest pump'n'dump for Basic Attention Token occurred on 2017-06-04 with a PnD ratio of 1.23
# The strongest pump'n'dump for Veritaseum occurred on 2017-06-11 with a PnD ratio of 33.55
# The strongest pump'n'dump for FunFair occurred on 2017-06-29 with a PnD ratio of 12.49
# The strongest pump'n'dump for TenX occurred on 2017-07-06 with a PnD ratio of 1.35
# The strongest pump'n'dump for Status occurred on 2017-11-29 with a PnD ratio of 1.39
# The strongest pump'n'dump for EOS occurred on 2017-07-03 with a PnD ratio of 1.32
# The strongest pump'n'dump for Gas occurred on 2017-09-14 with a PnD ratio of 1.48
# The strongest pump'n'dump for Metal occurred on 2017-11-20 with a PnD ratio of 1.67
# The strongest pump'n'dump for Populous occurred on 2017-09-11 with a PnD ratio of 3.72
# The strongest pump'n'dump for OmiseGO occurred on 2017-07-14 with a PnD ratio of 1.33
# The strongest pump'n'dump for Civic occurred on 2017-12-25 with a PnD ratio of 1.73
# The strongest pump'n'dump for Ethos occurred on 2017-08-05 with a PnD ratio of 1.37
# The strongest pump'n'dump for Binance Coin occurred on 2017-12-26 with a PnD ratio of 1.18
# The strongest pump'n'dump for Bitcoin Cash occurred on 2017-11-12 with a PnD ratio of 1.78
# The strongest pump'n'dump for 0x occurred on 2018-04-05 with a PnD ratio of 1.25
# The strongest pump'n'dump for VeChain occurred on 2017-12-27 with a PnD ratio of 1.27
# The strongest pump'n'dump for Nebulas occurred on 2017-11-17 with a PnD ratio of 1.18
# The strongest pump'n'dump for Waltonchain occurred on 2018-01-13 with a PnD ratio of 1.50
# The strongest pump'n'dump for Loopring occurred on 2017-09-23 with a PnD ratio of 4.53
# The strongest pump'n'dump for KingN Coin occurred on 2017-09-19 with a PnD ratio of 1.85
# The strongest pump'n'dump for TRON occurred on 2017-09-16 with a PnD ratio of 9.65
# The strongest pump'n'dump for Decentraland occurred on 2017-09-21 with a PnD ratio of 2.97
# The strongest pump'n'dump for SALT occurred on 2017-09-29 with a PnD ratio of 1.23
# The strongest pump'n'dump for Cardano occurred on 2017-10-01 with a PnD ratio of 1.29
# The strongest pump'n'dump for RChain occurred on 2017-10-08 with a PnD ratio of 5.08
# The strongest pump'n'dump for Enigma occurred on 2017-12-25 with a PnD ratio of 1.36
# The strongest pump'n'dump for Aion occurred on 2017-11-24 with a PnD ratio of 1.36
# The strongest pump'n'dump for KuCoin Shares occurred on 2017-10-25 with a PnD ratio of 1.32
# The strongest pump'n'dump for ICON occurred on 2017-12-16 with a PnD ratio of 1.25
# The strongest pump'n'dump for Power Ledger occurred on 2017-11-02 with a PnD ratio of 1.36
# The strongest pump'n'dump for QASH occurred on 2017-11-23 with a PnD ratio of 1.67
# The strongest pump'n'dump for Dragonchain occurred on 2018-01-02 with a PnD ratio of 1.21
# The strongest pump'n'dump for aelf occurred on 2018-01-05 with a PnD ratio of 1.28
# The strongest pump'n'dump for SIRIN LABS Token occurred on 2017-12-30 with a PnD ratio of 1.89
# The strongest pump'n'dump for Zilliqa occurred on 2018-03-05 with a PnD ratio of 1.46
# The strongest pump'n'dump for Polymath occurred on 2018-02-02 with a PnD ratio of 1.46
# The strongest pump'n'dump for Centrality occurred on 2018-04-07 with a PnD ratio of 1.18
# The strongest pump'n'dump for Loom Network occurred on 2018-03-14 with a PnD ratio of 1.53
# The strongest pump'n'dump for Cortex occurred on 2018-04-24 with a PnD ratio of 1.14

# %% [markdown]
# ## 4. ROI (1 point)

# %% [markdown]
# You need to calculate **return on investment (ROI)** in cryptocurrencies over a given period of time.
#
# Payback is defined as the ratio of *portfolio price change* to *portfolio initial price*. The portfolio price is the total value (in USD) of all coins in the portfolio.
#
# `investments` is a dictionary where the keys are the names of the coins, the values ​​are the amount of investments in this coin (in USD).

# %%
pd.options.mode.chained_assignment = "warn"

def compute_roi(coins, investments, start_date, end_date):
    d_range = coins.loc[start_date:end_date]

    value, final_value = sum(investments[coin] for coin in investments), 0

    for coin, investment_amount in investments.items():
        coin_data = d_range[d_range['symbol'] == coin]
        final_value += coin_data.iloc[-1]['close'] * investment_amount

    roi = (final_value - value) / value

    return roi

# %%
compute_roi(coins, investments={'BTC': 1000, 'LTC': 500}, start_date='2018-04-04', end_date='2018-06-01')
# Out:
# 5066.606666666667

# %%
compute_roi(coins, investments={'BTC': 1000, 'LTC': 500}, start_date='2013-05-28', end_date='2018-06-06')
# Out:
# 5142.046666666667

# %% [markdown]
# ## 5. Technical analysis (1 point)

# %% [markdown]
# **Technical analysis** is a way to predict the behavior of a chart based on some auxiliary values ​​built on the original chart. One of the simplest methods of technical analysis is **[Bollinger Bands](https://en.wikipedia.org/wiki/Bollinger_Bands)**. Someone believes that the graph touching the border should be reflected from it.
#
# Borders are considered very simply:
#
# $$(MA \pm K\sigma),$$
#
# where `MA` is the `N` day moving average and $\sigma$ is the `N` day moving standard deviation.

# %% [markdown]
# Draw **price chart**, **moving average** and **Bollinger bands** with parameters `N (window) = 21`, `K (width) = 2`.
#
# The `rolling` function will help you here to calculate the mean and standard deviation over a sliding window.
#
# Don't forget to label the graph and axes, draw the legend and choose the best location for it.

# %%
def plot_bollinger_bands(coins, symbol, window, width):
    # Paste your code here

# %%
plot_bollinger_bands(coins=coins, symbol='EOS', window=21, width=2)  # тут должен появиться график

# %% [markdown]
# **Conclude whether the Bollinger Rule was followed:**

# %% [markdown]
# **Your answer is here**

# %% [markdown]
# ## 6. Capitalization as an indicator (1 point)

# %% [markdown]
# Many people who trade cryptocurrencies like to look at [capitalization](https://academy.binance.com/en/articles/crypto-market-capitalization-explained). Let's understand why.

# %% [markdown]
# **Draw two more graphs:**
# 1. total capitalization of bitcoin (BTC), ether (ETH), eos (EOS), bitcoin cash (BCH), stellar (XLM) and litecoin (LTC)
# 2. shares of capitalizations of these coins from the total market capitalization.
#
# In this case, use the data starting from 2017-07-01.

# %%
def plot_coins_capitalizations(coins, symbols, start_date):
    s_coins = coins[(coins['symbol'].isin(symbols)) & (coins.index >= start_date)]
    coin_caps = {}

    for symbol in symbols:
        coin_data = s_coins[s_coins['symbol'] == symbol]
        coin_caps[symbol] = coin_data['market'].sum()

    # total market capitalization
    market_cap = sum(coin_caps.values())

    # Plotting total capitalizations
    plt.figure(figsize=(12, 6))
    plt.bar(coin_caps.keys(), coin_caps.values(), color='skyblue')
    plt.title('Total Capitalizations of Selected Coins')
    plt.xlabel('Cryptocurrency')
    plt.ylabel('Total Capitalization (in USD)')
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()

    # shares of capitalizations
    shares = {symbol: cap / market_cap for symbol, cap in coin_caps.items()}
    plt.figure(figsize=(8, 8))
    plt.pie(shares.values(), labels=shares.keys(), autopct='%1.1f%%', startangle=140)
    plt.title('Shares of Capitalizations from Total Market Capitalization')
    plt.show()

# %%
plot_coins_capitalizations(
    coins=coins,
    symbols=('BTC', 'ETH', 'EOS', 'BCH', 'XLM', 'LTC'),
    start_date='2017-07-01'
)

# %% [markdown]
# Analyze the dependence of the share of capitalization of altcoins (other coins, except for bitcoin) on the share of capitalization of bitcoin. What do you think is the reason for this dependence?

# %% [markdown]
# **Your answer is here**

# %% [markdown]
# ## 7. Coin correlations (1 point)

# %% [markdown]
# Now we need to take a closer look at the correlations of the average shares of coin capitalizations. In this case, we will look at the average smoothed over the last `window` days until the day `date` with a smoothing coefficient `alpha` for the set of coins `symbols`.
#
# Implement a function that will return a square `DataFrame` with the number of rows and columns equal to the number of coins in question and with correlation values:

# %%
def calc_coins_correlations(coins, date, symbols, window, alpha):
    s_coins = coins[(coins['symbol'].isin(symbols)) & (coins.index <= date)]
    pivot = s_coins.pivot(columns='symbol', values='market')

    data = pivot.ewm(alpha=alpha, min_periods=window).mean()
    correlations = data.rolling(window=window).corr(pairwise=True).dropna()

    corr = correlations.loc[date]

    return corr

# %%
correlations = calc_coins_correlations(coins, date="2018-06-06",
                                       symbols=['BTC', 'ETH', 'EOS', 'BCH', 'XLM', 'LTC', 'ADA'],
                                       window=21, alpha=0.1)
# Теперь посмотрим на эти корреляции следующим образом:
correlations.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <ipython-input-140-5cb301b2dfa8>:5: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   correlations.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_8d39f_row0_col0, #T_8d39f_row1_col1, #T_8d39f_row2_col2, #T_8d39f_row3_col3, #T_8d39f_row4_col4, #T_8d39f_row5_col5, #T_8d39f_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8d39f_row0_col1 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_8d39f_row0_col2, #T_8d39f_row2_col6 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_8d39f_row0_col3 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_8d39f_row0_col4 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_8d39f_row0_col5 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_8d39f_row0_col6, #T_8d39f_row1_col5, #T_8d39f_row6_col0 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_8d39f_row1_col0 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_8d39f_row1_col2, #T_8d39f_row1_col6, #T_8d39f_row6_col1, #T_8d39f_row6_col5 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_8d39f_row1_col3 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_8d39f_row1_col4 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_8d39f_row2_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_8d39f_row2_col1 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_8d39f_row2_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_8d39f_row2_col4 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_8d39f_row2_col5, #T_8d39f_row5_col2 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_8d39f_row3_col0, #T_8d39f_row3_col1, #T_8d39f_row3_col2, #T_8d39f_row3_col4, #T_8d39f_row3_col5, #T_8d39f_row3_col6, #T_8d39f_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8d39f_row4_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_8d39f_row4_col1 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_8d39f_row4_col2 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_8d39f_row4_col5 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_8d39f_row4_col6 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_8d39f_row5_col0 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_8d39f_row5_col1 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_8d39f_row5_col3 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_8d39f_row5_col4 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_8d39f_row5_col6 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_8d39f_row6_col2 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_8d39f_row6_col3 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_8d39f_row6_col4 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8d39f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th id="T_8d39f_level0_col0" class="col_heading level0 col0" >ADA</th>
#       <th id="T_8d39f_level0_col1" class="col_heading level0 col1" >BCH</th>
#       <th id="T_8d39f_level0_col2" class="col_heading level0 col2" >BTC</th>
#       <th id="T_8d39f_level0_col3" class="col_heading level0 col3" >EOS</th>
#       <th id="T_8d39f_level0_col4" class="col_heading level0 col4" >ETH</th>
#       <th id="T_8d39f_level0_col5" class="col_heading level0 col5" >LTC</th>
#       <th id="T_8d39f_level0_col6" class="col_heading level0 col6" >XLM</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d39f_level0_row0" class="row_heading level0 row0" >ADA</th>
#       <td id="T_8d39f_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_8d39f_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_8d39f_row0_col2" class="data row0 col2" >0.99</td>
#       <td id="T_8d39f_row0_col3" class="data row0 col3" >0.94</td>
#       <td id="T_8d39f_row0_col4" class="data row0 col4" >0.97</td>
#       <td id="T_8d39f_row0_col5" class="data row0 col5" >0.99</td>
#       <td id="T_8d39f_row0_col6" class="data row0 col6" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_8d39f_level0_row1" class="row_heading level0 row1" >BCH</th>
#       <td id="T_8d39f_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_8d39f_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_8d39f_row1_col2" class="data row1 col2" >1.00</td>
#       <td id="T_8d39f_row1_col3" class="data row1 col3" >0.93</td>
#       <td id="T_8d39f_row1_col4" class="data row1 col4" >0.98</td>
#       <td id="T_8d39f_row1_col5" class="data row1 col5" >1.00</td>
#       <td id="T_8d39f_row1_col6" class="data row1 col6" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_8d39f_level0_row2" class="row_heading level0 row2" >BTC</th>
#       <td id="T_8d39f_row2_col0" class="data row2 col0" >0.99</td>
#       <td id="T_8d39f_row2_col1" class="data row2 col1" >1.00</td>
#       <td id="T_8d39f_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_8d39f_row2_col3" class="data row2 col3" >0.90</td>
#       <td id="T_8d39f_row2_col4" class="data row2 col4" >0.99</td>
#       <td id="T_8d39f_row2_col5" class="data row2 col5" >1.00</td>
#       <td id="T_8d39f_row2_col6" class="data row2 col6" >0.99</td>
#     </tr>
#     <tr>
#       <th id="T_8d39f_level0_row3" class="row_heading level0 row3" >EOS</th>
#       <td id="T_8d39f_row3_col0" class="data row3 col0" >0.94</td>
#       <td id="T_8d39f_row3_col1" class="data row3 col1" >0.93</td>
#       <td id="T_8d39f_row3_col2" class="data row3 col2" >0.90</td>
#       <td id="T_8d39f_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_8d39f_row3_col4" class="data row3 col4" >0.86</td>
#       <td id="T_8d39f_row3_col5" class="data row3 col5" >0.91</td>
#       <td id="T_8d39f_row3_col6" class="data row3 col6" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_8d39f_level0_row4" class="row_heading level0 row4" >ETH</th>
#       <td id="T_8d39f_row4_col0" class="data row4 col0" >0.97</td>
#       <td id="T_8d39f_row4_col1" class="data row4 col1" >0.98</td>
#       <td id="T_8d39f_row4_col2" class="data row4 col2" >0.99</td>
#       <td id="T_8d39f_row4_col3" class="data row4 col3" >0.86</td>
#       <td id="T_8d39f_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_8d39f_row4_col5" class="data row4 col5" >0.99</td>
#       <td id="T_8d39f_row4_col6" class="data row4 col6" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_8d39f_level0_row5" class="row_heading level0 row5" >LTC</th>
#       <td id="T_8d39f_row5_col0" class="data row5 col0" >0.99</td>
#       <td id="T_8d39f_row5_col1" class="data row5 col1" >1.00</td>
#       <td id="T_8d39f_row5_col2" class="data row5 col2" >1.00</td>
#       <td id="T_8d39f_row5_col3" class="data row5 col3" >0.91</td>
#       <td id="T_8d39f_row5_col4" class="data row5 col4" >0.99</td>
#       <td id="T_8d39f_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_8d39f_row5_col6" class="data row5 col6" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_8d39f_level0_row6" class="row_heading level0 row6" >XLM</th>
#       <td id="T_8d39f_row6_col0" class="data row6 col0" >1.00</td>
#       <td id="T_8d39f_row6_col1" class="data row6 col1" >1.00</td>
#       <td id="T_8d39f_row6_col2" class="data row6 col2" >0.99</td>
#       <td id="T_8d39f_row6_col3" class="data row6 col3" >0.93</td>
#       <td id="T_8d39f_row6_col4" class="data row6 col4" >0.97</td>
#       <td id="T_8d39f_row6_col5" class="data row6 col5" >1.00</td>
#       <td id="T_8d39f_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It is quite interesting to take another look at 2017-12-27:

# %%
correlations = calc_coins_correlations(coins, date="2017-12-27",
                                       symbols=['BTC', 'ETH', 'EOS', 'BCH', 'XLM', 'LTC', 'ADA'],
                                       window=21, alpha=0.1)
# Теперь посмотрим на эти корреляции следующим образом:
correlations.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <ipython-input-141-c2d058096282>:5: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   correlations.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_3bc46_row0_col0, #T_3bc46_row1_col1, #T_3bc46_row2_col2, #T_3bc46_row3_col3, #T_3bc46_row4_col4, #T_3bc46_row5_col5, #T_3bc46_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3bc46_row0_col1 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_3bc46_row0_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_3bc46_row0_col3, #T_3bc46_row5_col4 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_3bc46_row0_col4 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_3bc46_row0_col5 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_3bc46_row0_col6 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_3bc46_row1_col0 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_3bc46_row1_col2, #T_3bc46_row1_col5, #T_3bc46_row2_col0, #T_3bc46_row2_col1, #T_3bc46_row2_col3, #T_3bc46_row2_col4, #T_3bc46_row2_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3bc46_row1_col3 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_3bc46_row1_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_3bc46_row1_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_3bc46_row2_col5 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_3bc46_row3_col0 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_3bc46_row3_col1, #T_3bc46_row5_col3 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_3bc46_row3_col2 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_3bc46_row3_col4 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_3bc46_row3_col5, #T_3bc46_row5_col2 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_3bc46_row3_col6, #T_3bc46_row4_col6 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_3bc46_row4_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_3bc46_row4_col1 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_3bc46_row4_col2 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_3bc46_row4_col3 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_3bc46_row4_col5 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_3bc46_row5_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_3bc46_row5_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_3bc46_row5_col6 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_3bc46_row6_col0, #T_3bc46_row6_col5 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_3bc46_row6_col1 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_3bc46_row6_col2 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_3bc46_row6_col3 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_3bc46_row6_col4 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3bc46" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th id="T_3bc46_level0_col0" class="col_heading level0 col0" >ADA</th>
#       <th id="T_3bc46_level0_col1" class="col_heading level0 col1" >BCH</th>
#       <th id="T_3bc46_level0_col2" class="col_heading level0 col2" >BTC</th>
#       <th id="T_3bc46_level0_col3" class="col_heading level0 col3" >EOS</th>
#       <th id="T_3bc46_level0_col4" class="col_heading level0 col4" >ETH</th>
#       <th id="T_3bc46_level0_col5" class="col_heading level0 col5" >LTC</th>
#       <th id="T_3bc46_level0_col6" class="col_heading level0 col6" >XLM</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bc46_level0_row0" class="row_heading level0 row0" >ADA</th>
#       <td id="T_3bc46_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_3bc46_row0_col1" class="data row0 col1" >0.97</td>
#       <td id="T_3bc46_row0_col2" class="data row0 col2" >0.84</td>
#       <td id="T_3bc46_row0_col3" class="data row0 col3" >0.99</td>
#       <td id="T_3bc46_row0_col4" class="data row0 col4" >0.98</td>
#       <td id="T_3bc46_row0_col5" class="data row0 col5" >0.95</td>
#       <td id="T_3bc46_row0_col6" class="data row0 col6" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_3bc46_level0_row1" class="row_heading level0 row1" >BCH</th>
#       <td id="T_3bc46_row1_col0" class="data row1 col0" >0.97</td>
#       <td id="T_3bc46_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_3bc46_row1_col2" class="data row1 col2" >0.73</td>
#       <td id="T_3bc46_row1_col3" class="data row1 col3" >0.95</td>
#       <td id="T_3bc46_row1_col4" class="data row1 col4" >0.94</td>
#       <td id="T_3bc46_row1_col5" class="data row1 col5" >0.88</td>
#       <td id="T_3bc46_row1_col6" class="data row1 col6" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_3bc46_level0_row2" class="row_heading level0 row2" >BTC</th>
#       <td id="T_3bc46_row2_col0" class="data row2 col0" >0.84</td>
#       <td id="T_3bc46_row2_col1" class="data row2 col1" >0.73</td>
#       <td id="T_3bc46_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_3bc46_row2_col3" class="data row2 col3" >0.89</td>
#       <td id="T_3bc46_row2_col4" class="data row2 col4" >0.91</td>
#       <td id="T_3bc46_row2_col5" class="data row2 col5" >0.96</td>
#       <td id="T_3bc46_row2_col6" class="data row2 col6" >0.92</td>
#     </tr>
#     <tr>
#       <th id="T_3bc46_level0_row3" class="row_heading level0 row3" >EOS</th>
#       <td id="T_3bc46_row3_col0" class="data row3 col0" >0.99</td>
#       <td id="T_3bc46_row3_col1" class="data row3 col1" >0.95</td>
#       <td id="T_3bc46_row3_col2" class="data row3 col2" >0.89</td>
#       <td id="T_3bc46_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_3bc46_row3_col4" class="data row3 col4" >1.00</td>
#       <td id="T_3bc46_row3_col5" class="data row3 col5" >0.98</td>
#       <td id="T_3bc46_row3_col6" class="data row3 col6" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_3bc46_level0_row4" class="row_heading level0 row4" >ETH</th>
#       <td id="T_3bc46_row4_col0" class="data row4 col0" >0.98</td>
#       <td id="T_3bc46_row4_col1" class="data row4 col1" >0.94</td>
#       <td id="T_3bc46_row4_col2" class="data row4 col2" >0.91</td>
#       <td id="T_3bc46_row4_col3" class="data row4 col3" >1.00</td>
#       <td id="T_3bc46_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_3bc46_row4_col5" class="data row4 col5" >0.99</td>
#       <td id="T_3bc46_row4_col6" class="data row4 col6" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_3bc46_level0_row5" class="row_heading level0 row5" >LTC</th>
#       <td id="T_3bc46_row5_col0" class="data row5 col0" >0.95</td>
#       <td id="T_3bc46_row5_col1" class="data row5 col1" >0.88</td>
#       <td id="T_3bc46_row5_col2" class="data row5 col2" >0.96</td>
#       <td id="T_3bc46_row5_col3" class="data row5 col3" >0.98</td>
#       <td id="T_3bc46_row5_col4" class="data row5 col4" >0.99</td>
#       <td id="T_3bc46_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_3bc46_row5_col6" class="data row5 col6" >0.99</td>
#     </tr>
#     <tr>
#       <th id="T_3bc46_level0_row6" class="row_heading level0 row6" >XLM</th>
#       <td id="T_3bc46_row6_col0" class="data row6 col0" >0.98</td>
#       <td id="T_3bc46_row6_col1" class="data row6 col1" >0.93</td>
#       <td id="T_3bc46_row6_col2" class="data row6 col2" >0.92</td>
#       <td id="T_3bc46_row6_col3" class="data row6 col3" >1.00</td>
#       <td id="T_3bc46_row6_col4" class="data row6 col4" >1.00</td>
#       <td id="T_3bc46_row6_col5" class="data row6 col5" >0.99</td>
#       <td id="T_3bc46_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 8. Analysis of one strategy (2 points)

# %% [markdown]
# Let's take a dreamy example. Let's see how much profit a textbook trading strategy based on moving averages could bring us.
#
# The strategy looks like this: we build two moving averages for the price chart. With a small window (leading moving average) and with a large window (lagging moving average). **We buy when the leading average becomes larger than the lagging one and sell otherwise.**
#
# Let's look at an example:

# %%
def plot_moving_averages(coins, symbol, leading_window, lagging_window, start_date, end_date):
    coin = coins[coins['symbol'] == symbol][start_date:end_date]
    price = coin['price']
    leading_mean = price.rolling(window=leading_window).mean()
    lagging_mean = price.rolling(window=lagging_window).mean()

    fig = plt.figure(figsize=(16, 9))
    ax = fig.add_subplot(111)

    ax.set_title('Price action for {}'.format(symbol))
    ax.plot(leading_mean, color='green', label='MA{}'.format(leading_window))
    ax.plot(lagging_mean, color='red', label='MA{}'.format(lagging_window))
    ax.plot(price, color='blue', label='price')
    ax.set_xlabel('Date')
    ax.set_ylabel('Price')
    ax.legend(loc='best')
    ax.grid(True)
    plt.show()

plot_moving_averages(
    coins=coins,
    symbol='BTC',
    leading_window=21,
    lagging_window=50,
    start_date='2017-05-01',
    end_date='2018-08-01')

# %% [markdown]
# It can be seen that the moving average with a larger window reacts more slowly to price changes. It is on this idea that the trading strategy is based.
#
#
# **Implement a function** that draws two graphs. The right side will display the price and moving averages. On the left - how many times the size of investments will change when using our strategy and with ordinary investment (we bought and hold, we look at how the price of our purchased currencies grows).

# %% [markdown]
# >**Notes:**
# >- Let's use only closing prices. In this case, to find out the prices for yesterday, you should use the `shift (1)` method for `Series`.
# >- The ratio of closing prices for today and yesterday is **multiplier** for today. At the same time, let's build accumulation graphs for multipliers. Those. if we look at 3 days and on the first day multiplier = 1.5, on the second - 0.5 and on the third - 2, then the graph will look like this: (1.5, 1.5 *0.5, 1.5* 0.5 * 2).
# >- When using our new strategy, we will either buy if the leading average becomes larger than the lagging one by some `threshold` (in this case, it is better to divide the difference by the price first), or leave everything as it is. At the same time, of course, when making decisions for today, you need to look only at statistics from the past.

# %%
def plot_moving_averages_strategy(
    coins, symbol, lead_window, lag_window, threshold, start_date, end_date
):
    # Paste your code here

# %%
# Теперь на основе реализованной функции сделаем интерактивные графики и поизучаем, что получилось:
symbol_selector = ipywidgets.Dropdown(
    options=('BTC', 'ETH', 'EOS', 'BCH', 'XLM', 'LTC', 'ADA'),
    index=0,
    value='BTC',
    layout={'width': '700px'},
    continuous_update=False
)

lead_window_slider = ipywidgets.IntSlider(
    value=21,
    min=1,
    max=200,
    step=1,
    layout={'width': '700px'},
    continuous_update=False)

lag_window_slider = ipywidgets.IntSlider(
    value=50,
    min=1,
    max=200,
    layout={'width': '700px'},
    step=1, continuous_update=False)

threshold_slider = ipywidgets.FloatSlider(
    min=0,
    max=0.20,
    step=0.001,
    value=0.025,
    layout={'width': '700px'},
    continuous_update=False)

start_date_slider = ipywidgets.SelectionSlider(
    options=pd.date_range('2013-04-28', '2018-06-06', freq='D'),
    index=0,
    value=pd.Timestamp('2017-05-01'),
    layout={'width': '700px'},
    continuous_update=False
)

end_date_slider = ipywidgets.SelectionSlider(
    options=pd.date_range('2013-04-28', '2018-06-06', freq='D'),
    index=0,
    value=pd.Timestamp('2018-01-01'),
    layout={'width': '700px'},
    continuous_update=False
)

ipywidgets.interact(
    plot_moving_averages_strategy,
    coins=ipywidgets.fixed(coins),
    symbol=symbol_selector,
    lead_window=lead_window_slider,
    lag_window=lag_window_slider,
    threshold=threshold_slider,
    start_date=start_date_slider,
    end_date=end_date_slider
)

# %% [markdown]
# Try different parameter values ​​for different coins and draw conclusions about the applicability of such a model:

# %% [markdown]
# **Your answer is here**

# %% [markdown]
# ## 9. Disclaimer

# %% [markdown]
# All examples of the strategies analyzed here are toys and are not suitable for real trading on the stock exchange. Without serious preparation, you will be eaten there with giblets.
